# %% [markdown]
# # Task 2B - Find Likelihood to be Bad Actor
#
# ## Task Updates for Case Competition Final
# - Apply SMOTE and upsampling to address Class Imbalance issue
# - Apply additional hyperparameter tuning
# - Add One-Class SVM and Isolation Forest models

# %% [markdown]
# ## Library and Pre-process

# %%
# Basic library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Scikit-Learn library
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, SGDOneClassSVM
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, IsolationForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, auc,\
                            confusion_matrix, roc_curve

# Resampling library
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
# Read main dataset
df = pd.read_csv('UofT_nodes.csv')
df_bad_list = pd.read_csv('badactor_foundin_kyc_bt_match.csv')

# Read main dataset (other directiry version)
# df = pd.read_csv('data/UofT_nodes.csv')
# df_bad_list = pd.read_csv('0_final_badactors_list.csv')

# %%
# Change all to categorical
df['COUNTRY_RISK_INCOME'] = df['COUNTRY_RISK_INCOME'].astype('category').cat.codes
df['COUNTRY_RISK_RESIDENCY'] = df['COUNTRY_RISK_RESIDENCY'].astype('category').cat.codes
df['GENDER'] = df['GENDER'].astype('category').cat.codes

df['RISK'] = df['RISK'].replace(['low'], 0)
df['RISK'] = df['RISK'].replace(['medium'], 1)
df['RISK'] = df['RISK'].replace(['high'], 2)

# %%
# Convert Key(Customer ID) to int for join
df.CUSTOMER_ID = df.CUSTOMER_ID.astype(float).astype(int)
df_bad_list.CUSTOMER_ID = df_bad_list.CUSTOMER_ID.astype(float).astype(int)

# Change all date to date format
df.BIRTH_DT = pd.to_datetime(df.BIRTH_DT)
df.CUST_ADD_DT = pd.to_datetime(df.CUST_ADD_DT)

# Fill NaN with value different from the other
# noinspection PyTypeChecker
df.CUST_ADD_DT.fillna(pd.Timestamp('2023-01-01'), inplace=True)
df.OCPTN_NM.fillna(-1, inplace=True)

# Convert all dates to Unix timestamps for modeling (values are not intuitive)
# df['BIRTH_TS'] = df['BIRTH_DT'].apply(lambda x: x.timestamp())
# df['CUST_ADD_TS'] = df['CUST_ADD_DT'].apply(lambda x: x.timestamp())

# Generate new features for feature selection
df['BIRTH_DU'] = pd.Timestamp('2022-12-31') - df['BIRTH_DT']
df['CUST_ADD_DU'] = pd.Timestamp('2022-12-31') - df['CUST_ADD_DT']
df['BIRTH_DU'] = df['BIRTH_DU'].astype('int64') // (10**9 * 86400 * 365)
df['CUST_ADD_DU'] = df['CUST_ADD_DU'].astype('int64') // (10**9 * 86400 * 365)

# See data heath of main dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   BIRTH_DT                1000000 non-null  datetime64[ns]
#  1   CUST_ADD_DT             1000000 non-null  datetime64[ns]
#  2   OCPTN_NM                1000000 non-null  float64
#  3   RES_CNTRY_CA            1000000 non-null  int64
#  4   CNTRY_OF_INCOME_CA      1000000 non-null  int64
#  5   PEP_FL                  1000000 non-null  float64
#  6   CASH_SUM_IN             1000000 non-null  float64
#  7   CASH_CNT_IN             1000000 non-null  float64
#  8   CASH_SUM_OUT            1000000 non-null  float64
#  9   CASH_CNT_OUT            1000000 non-null  float64
#  10  WIRES_SUM_IN            1000000 non-null  float64
#  11  WIRES_CNT_IN            1000000 non-null  float64
#  12  WIRES_SUM_OUT           1000000 non-null  float64
#  13  WIRES_CNT_OUT           1000000 non-null  float64
#  14  COUNTRY_RISK_INCOME     1000000 non-null  int8
#  15  COUNTRY_RISK_RESIDENCY  1000000 non-null  int8
#  16  RISK                    1000000 non-null  int64
#  17  NAME                    999340 non-null   object
#  18  GENDER                  1000000 non-null  int8
#  19  CUSTOMER_ID             1000000 non-null  int32
#  20  BIRTH_DU                1000000 non-null  int64
#  21  CUST_ADD_DU             1000000 non-null  int64
# dtypes: datetime64[ns](2), float64(10), int32(1), int64(5), int8(3), object(1)
# memory usage: 144.0+ MB

# %%
# See data heath of bad actors dataset
df_bad_list.CUSTOMER_ID = df_bad_list.CUSTOMER_ID.astype(float).astype(int)
df_bad_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              50 non-null     int64
#  1   BIRTH_DT                50 non-null     object
#  2   CUST_ADD_DT             50 non-null     object
#  3   OCPTN_NM                50 non-null     float64
#  4   RES_CNTRY_CA            50 non-null     int64
#  5   CNTRY_OF_INCOME_CA      50 non-null     int64
#  6   PEP_FL                  50 non-null     float64
#  7   CASH_SUM_IN             50 non-null     float64
#  8   CASH_CNT_IN             50 non-null     float64
#  9   CASH_SUM_OUT            50 non-null     float64
#  10  CASH_CNT_OUT            50 non-null     float64
#  11  WIRES_SUM_IN            50 non-null     float64
#  12  WIRES_CNT_IN            50 non-null     float64
#  13  WIRES_SUM_OUT           50 non-null     float64
#  14  WIRES_CNT_OUT           50 non-null     float64
#  15  COUNTRY_RISK_INCOME     50 non-null     object
#  16  COUNTRY_RISK_RESIDENCY  50 non-null     object
#  17  RISK                    50 non-null     object
#  18  NAME                    50 non-null     object
#  19  GENDER                  50 non-null     object
#  20  CUSTOMER_ID             50 non-null     int32
# dtypes: float64(10), int32(1), int64(3), object(7)
# memory usage: 8.1+ KB

# %%
# Create bad actor label
df_bad_list['BAD_STATUS'] = [True]*df_bad_list.shape[0] # Create True labels for real bad actors 
df = df.merge(df_bad_list[['BAD_STATUS', 'CUSTOMER_ID']], on='CUSTOMER_ID', how='left') # Join
df['BAD_STATUS'].fillna(False, inplace=True) # Fill the rest with False labels

# Check whether merged correctly
set(df_bad_list.CUSTOMER_ID) == set(df[df['BAD_STATUS']].CUSTOMER_ID)
# Out:
# True

# %%
# Show data distribution on BAD_STATUS
bad_count = df.groupby('BAD_STATUS').count()['NAME'].reset_index()
bad_count.rename(columns={'BAD_STATUS':'Bad Actor', 'NAME':'Count'}, inplace=True)
bad_count['Percentage'] = bad_count['Count']/sum(bad_count['Count'])
bad_count
# Out:
#    Bad Actor   Count  Percentage
# 0      False  999290     0.99995
# 1       True      50     0.00005

# %% [markdown]
# ## Variable Selection

# %%
# Set variable will be used for training, exclude ground truth features like 'Name'
column_feature = df.columns[2:17].to_list() + df.columns[20:-1].to_list()

# Show all features
#column_feature.remove('RISK')
column_feature
# Out:
# ['OCPTN_NM',
#  'RES_CNTRY_CA',
#  'CNTRY_OF_INCOME_CA',
#  'PEP_FL',
#  'CASH_SUM_IN',
#  'CASH_CNT_IN',
#  'CASH_SUM_OUT',
#  'CASH_CNT_OUT',
#  'WIRES_SUM_IN',
#  'WIRES_CNT_IN',
#  'WIRES_SUM_OUT',
#  'WIRES_CNT_OUT',
#  'COUNTRY_RISK_INCOME',
#  'COUNTRY_RISK_RESIDENCY',
#  'RISK',
#  'BIRTH_DU',
#  'CUST_ADD_DU']

# %%
# Split
X = df[column_feature]
y = df['BAD_STATUS']

# Feature selection with correlation calculation
corr = X.corrwith(y)

# Get the selected feature names
k = 10
indices = corr.abs().sort_values(ascending=False)[:15].index
selected_features = X[indices].columns.tolist()
X = X[selected_features]

# Show features
selected_features
# Out:
# ['COUNTRY_RISK_INCOME',
#  'CNTRY_OF_INCOME_CA',
#  'RISK',
#  'RES_CNTRY_CA',
#  'CASH_SUM_IN',
#  'COUNTRY_RISK_RESIDENCY',
#  'CASH_CNT_IN',
#  'WIRES_CNT_OUT',
#  'CASH_CNT_OUT',
#  'CASH_SUM_OUT',
#  'BIRTH_DU',
#  'WIRES_SUM_OUT',
#  'OCPTN_NM',
#  'WIRES_SUM_IN',
#  'PEP_FL']

# %% [markdown]
# ## Logistic Regression Modelling

# %%
# Training the logistic regression model with resampling methods
def train_lr(X_train_norm:pd.DataFrame,
             y_train:pd.DataFrame,
             lr_model:LogisticRegression or SGDOneClassSVM,
             iter:int = 10,
             rand_seed:int = 40,
             resample:str = None):
    
    # Check resample method input sanity
    if resample:
        assert resample=='ROS' or resample=='SMOTE',\
            f"resample can only be 'ROS'or 'SMOTE'"
    
    # Initialize an empty list to store the accuracy scores
    acc_scores = []
    prec_scores = []
    rec_scores = []
    spec_scores = []

    # Apply different resampling method to enlarge the bad actor sample size
    if resample == 'ROS': # Random Oversampling
        ros = RandomOverSampler(random_state=rand_seed)
        X_train_norm, y_train = ros.fit_resample(X_train_norm, y_train)
        print("Random oversampling actor distribution:")
        print(pd.Series(y_train).value_counts())
    elif resample == 'SMOTE': # Synthetic Minority Oversampling Technique
        smote = SMOTE(random_state=rand_seed)
        X_train_norm, y_train = smote.fit_resample(X_train_norm, y_train)
        print("SMOTE oversampling actor distribution:")
        print(pd.Series(y_train).value_counts())
    else: # No resampling
        print("Original actor distribution:")
        print(pd.Series(y_train).value_counts())
 
    for i in range(iter):
        # Split into training and validating sets
        X_ttrain, X_valid, y_ttrain, y_valid =\
            train_test_split(X_train_norm, y_train, stratify=y_train,
                              test_size=.2, random_state=rand_seed+i)
        
        # Train with the normalized training data
        lr_model.fit(X_ttrain, y_ttrain)
        
        # Evaluate the normalized validating data
        y_pred = lr_model.predict(X_valid)
        if type(lr_model) == SGDOneClassSVM:
            y_pred = np.where(y_pred == -1, 0, 1)
        accuracy = accuracy_score(y_valid, y_pred)
        precison = precision_score(y_valid, y_pred)
        recall = recall_score(y_valid, y_pred)
        specificity = recall_score(y_valid, y_pred, pos_label=0)

        # Add validation results to lists
        acc_scores.append(accuracy)
        prec_scores.append(precison)
        rec_scores.append(recall)
        spec_scores.append(specificity)

    # Show final result
    print('Average validation accuracy:', round(np.mean(acc_scores), 4))
    print('Average validation precision:', round(np.mean(prec_scores), 4))
    print('Average validation recall:', round(np.mean(rec_scores), 4))
    print('Average validation specificity:', round(np.mean(spec_scores), 4))

    # Return model results
    return lr_model, (np.mean(acc_scores), np.mean(prec_scores), np.mean(rec_scores), np.mean(spec_scores))

# Testing the logistic regression model with the test set
def test_lr(X_test:pd.DataFrame,
            y_test:pd.DataFrame,
            lr_model:LogisticRegression):
    
    # Generate test metrics
    y_test_pred = lr_model.predict(X_test)
    if type(lr_model) == SGDOneClassSVM:
        y_test_pred = np.where(y_test_pred == -1, 0, 1)

    # Metric result
    accuracy = accuracy_score(y_test, y_test_pred)
    precison = precision_score(y_test, y_test_pred)
    recall = recall_score(y_test, y_test_pred)
    specificity = recall_score(y_test, y_test, pos_label=0)

    # Show final result
    print('Test accuracy:', round(accuracy, 4))
    print('Test precision:', round(precison, 4))
    print('Test recall:', round(recall, 4))
    print('Test specificity:', round(specificity, 4))
    return (accuracy, precison, recall, specificity)

# %%
# Show the confusion matrix with complete set
def show_confusion(model:LogisticRegression or DecisionTreeClassifier or RandomForestClassifier or SGDOneClassSVM or IsolationForest,
                   scaler_model:StandardScaler,
                   df:pd.DataFrame,
                   feat_list:list,
                   c:int = 0.5):
    
    # Get the whole X back and normalize for linear models
    if (type(model) == LogisticRegression) or (type(model) == SGDOneClassSVM):
        X_all = scaler_model.transform(df[feat_list].values)
    else:
        X_all = df[feat_list].values

    if (type(model) == SGDOneClassSVM) or (type(model) == IsolationForest):
        bad_score = model.predict(X_all)
    else:
        bad_score = model.predict_proba(X_all)
        
    # y_true: the true class labels
    # y_pred: the predicted class labels
    y_true = df['BAD_STATUS']
    
    if (type(model) == SGDOneClassSVM) or (type(model) == IsolationForest):
        y_pred = model.predict(X_all)
        y_pred = np.where(y_pred == -1, 0, 1).astype(bool)
    else:
        y_pred = (model.predict_proba(X_all)[:,1] >= c).astype(bool) # can change threshold
    cm = confusion_matrix(y_true, y_pred)

    # Define class labels
    class_names = ['Normal', 'Bad']

    # Create a heatmap of the confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)

    # Add labels to the plot
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    # Return final likelihood of being a bad actor
    return bad_score, cm

# %%
# Show the coefficient with train set
def plot_coefficient(model:LogisticRegression or DecisionTreeClassifier or RandomForestClassifier or SGDOneClassSVM or IsolationForest,
                     X_train:pd.DataFrame):

    # Check if model is tree
    is_tree = type(model) == (DecisionTreeClassifier) or (type(model) == RandomForestClassifier) or (type(model) == IsolationForest)

    # Plot
    #plt.figure(figsize=(18,9))
    if not is_tree:
        ind_sort = np.argsort(abs(model.coef_[0]))[::-1]
        names = [X_train.columns[i] for i in ind_sort]
        plt.bar(names, model.coef_[0][ind_sort])
        count = sum(abs(model.coef_[0]) > 0)
    else:
        ind_sort = np.argsort(abs(model.feature_importances_))[::-1]
        names = [X_train.columns[i] for i in ind_sort]
        plt.bar(names, model.feature_importances_[ind_sort])
        count = sum(abs(model.feature_importances_) > 0)
    plt.xticks(rotation=90)
    plt.title('Coefficient Plot with %d Features' % count)
    plt.show()

# %%
# Plot confusion matrix and ROC curves of train/test set and calculate precision/recall
def plot_cm_roc(model:LogisticRegression or DecisionTreeClassifier or RandomForestClassifier or SGDOneClassSVM or IsolationForest,
                X_train:pd.DataFrame,
                X_test:pd.DataFrame,
                y_train:pd.DataFrame,
                y_test:pd.DataFrame):
    
    # Testing set results
    y_test_predicted = model.predict(X_test)
    if (type(model) == SGDOneClassSVM) or (type(model) == IsolationForest):
        y_test_predicted = np.where(y_test_predicted == -1, 0, 1)
    cm_test = confusion_matrix(y_test, y_test_predicted)

    # Define class labels
    class_names = ['Normal', 'Bad']

    # Create a heatmap of the confusion matrix
    sns.heatmap(cm_test, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)

    # Add labels to the plot
    plt.title('Confusion Matrix - Test')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    # Training set results
    y_train_predicted = model.predict(X_train)
    if (type(model) == SGDOneClassSVM) or (type(model) == IsolationForest):
        y_train_predicted = np.where(y_train_predicted == -1, 0, 1)
    cm_train = confusion_matrix(y_train, y_train_predicted)

    # Create a heatmap of the confusion matrix
    sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)

    # Add labels to the plot
    plt.title('Confusion Matrix - Train')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    
    if (type(model) == LogisticRegression) or (type(model) == DecisionTreeClassifier) or (type(model) == RandomForestClassifier):
        # ROC result of train and test set
        fpr_train, tpr_train, _ = roc_curve(y_train, model.predict_proba(X_train)[:, 1])
        fpr_test, tpr_test, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    else:
        fpr_train, tpr_train, _ = roc_curve(y_train, model.score_samples(X_train))
        fpr_test, tpr_test, _ = roc_curve(y_test, model.score_samples(X_test))

    # AUC result of train and test set
    auc_train = auc(fpr_train, tpr_train)
    auc_test  = auc(fpr_test, tpr_test)

    # Plot ROC curves of train and test set
    plt.plot(fpr_train, tpr_train, label='Train set | AUC of {:4.3f}'.format(auc_train))
    plt.plot(fpr_test, tpr_test, label='Test set | AUC of {:4.3f}'.format(auc_test))
    plt.plot([0,1], [0,1], color = 'k', linestyle = '--', label = 'Random | AUC of 0.5')
    plt.ylim([0,1.0])
    plt.xlim([0,1.0])
    plt.title('ROC Curve of Train and Test')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.legend()
    plt.show()

# %%
# Split a testing set, stratify to ensure there is 0.2% bad actor in test set
scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=.2, random_state=40)

# Normalize the X dataset
X_train_norm = scaler.fit_transform(X_train)
X_test_norm = scaler.transform(X_test)

# %% [markdown]
# ## LRs Perfromance Analysis

# %%
# Basic logistic regression approach
lr = LogisticRegression(random_state=7)

# Hide this warning: 
# Precision is ill-defined 
# and being set to 0.0 in labels with no predicted samples.
warnings.filterwarnings("ignore") 

# Train and test
lr, mm1 = train_lr(X_train_norm, y_train, lr)
m1 = test_lr(X_test_norm, y_test, lr)

# Show confusion matrix
bad1, cm1 = show_confusion(lr, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(lr, X_train_norm, X_test_norm, y_train, y_test)

# Show coef of training set
plot_coefficient(lr, X_train) # need X_train's column names
# Out:
# Original actor distribution:
# False    799960
# True         40
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.9999
# Average validation precision: 0.0
# Average validation recall: 0.0
# Average validation specificity: 1.0
# Test accuracy: 1.0
# Test precision: 0.0
# Test recall: 0.0
# Test specificity: 1.0

# %%
# Weighted sklearn hyperparameter approach
lr_sklearn = LogisticRegression(class_weight='balanced', random_state=7)

# Train and test
lr_sklearn, mm2  = train_lr(X_train_norm, y_train, lr_sklearn)
m2 = test_lr(X_test_norm, y_test, lr_sklearn)

# Show confusion matrix
bad2, cm2 = show_confusion(lr_sklearn, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(lr_sklearn, X_train_norm, X_test_norm, y_train, y_test)

# Show coef of training set
plot_coefficient(lr_sklearn, X_train) # need X_train's column names
# Out:
# Original actor distribution:
# False    799960
# True         40
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.8585
# Average validation precision: 0.0002
# Average validation recall: 0.6625
# Average validation specificity: 0.8585
# Test accuracy: 0.8584
# Test precision: 0.0002
# Test recall: 0.7
# Test specificity: 1.0

# %%
# SMOTE approach
lr_smote = LogisticRegression(random_state=7)

# Train and test
lr_smote, mm3 = train_lr(X_train_norm, y_train, lr_smote, resample='SMOTE')
m3 = test_lr(X_test_norm, y_test, lr_smote)

# Show confusion matrix
bad3, cm3 = show_confusion(lr_smote, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(lr_smote, X_train_norm, X_test_norm, y_train, y_test)

# Show coef of training set
plot_coefficient(lr_smote, X_train) # need X_train's column names
# Out:
# SMOTE oversampling actor distribution:
# False    799960
# True     799960
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.7884
# Average validation precision: 0.8585
# Average validation recall: 0.6907
# Average validation specificity: 0.8862
# Test accuracy: 0.8865
# Test precision: 0.0004
# Test recall: 0.8
# Test specificity: 1.0

# %%
# ROS approach
lr_ros = LogisticRegression(random_state=7)

# Train and test
lr_ros, mm4 = train_lr(X_train_norm, y_train, lr_ros, resample='ROS')
m4 = test_lr(X_test_norm, y_test, lr_ros)

# Show confusion matrix
bad4, cm4 = show_confusion(lr_ros, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(lr_ros, X_train_norm, X_test_norm, y_train, y_test)

# Show coef of training set
plot_coefficient(lr_ros, X_train) # need X_train's column names
# Out:
# Random oversampling actor distribution:
# False    799960
# True     799960
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.7846
# Average validation precision: 0.8429
# Average validation recall: 0.6996
# Average validation specificity: 0.8696
# Test accuracy: 0.8699
# Test precision: 0.0003
# Test recall: 0.7
# Test specificity: 1.0

# %% [markdown]
# ## One-Class SVM Performance Analysis

# %%
# Basic logistic regression approach
svm = SGDOneClassSVM(random_state=42)

# Hide this warning: 
# Precision is ill-defined 
# and being set to 0.0 in labels with no predicted samples.
warnings.filterwarnings("ignore") 

# Train and test
svm, mm5 = train_lr(X_train_norm, y_train, svm)
m5 = test_lr(X_test_norm, y_test, svm)

# Show confusion matrix
bad5, cm5 = show_confusion(svm, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(svm, X_train_norm, X_test_norm, y_train, y_test)
# Out:
# Original actor distribution:
# False    799960
# True         40
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.481
# Average validation precision: 0.0001
# Average validation recall: 0.525
# Average validation specificity: 0.481
# Test accuracy: 0.5205
# Test precision: 0.0001
# Test recall: 0.7
# Test specificity: 1.0

# %%
# SMOTE approach
svm_smote = SGDOneClassSVM(random_state=42)

# Train and test
svm_smote, mm6 = train_lr(X_train_norm, y_train, svm_smote, resample='SMOTE')
m6 = test_lr(X_test_norm, y_test, svm_smote)

# Show confusion matrix
bad6, cm6 = show_confusion(svm_smote, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(svm_smote, X_train_norm, X_test_norm, y_train, y_test)
# Out:
# SMOTE oversampling actor distribution:
# False    799960
# True     799960
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.7016
# Average validation precision: 0.7019
# Average validation recall: 0.7143
# Average validation specificity: 0.6889
# Test accuracy: 0.6834
# Test precision: 0.0001
# Test recall: 0.7
# Test specificity: 1.0

# %%
# ROS approach
svm_ros = SGDOneClassSVM(random_state=42)

# Train and test
svm_ros, mm7 = train_lr(X_train_norm, y_train, svm_smote, resample='ROS')
m7 = test_lr(X_test_norm, y_test, svm_smote)

# Show confusion matrix
bad7, cm7 = show_confusion(svm_ros, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(svm_ros, X_train_norm, X_test_norm, y_train, y_test)
# Out:
# Random oversampling actor distribution:
# False    799960
# True     799960
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.7086
# Average validation precision: 0.7067
# Average validation recall: 0.7251
# Average validation specificity: 0.6921
# Test accuracy: 0.507
# Test precision: 0.0001
# Test recall: 0.7
# Test specificity: 1.0

# %% [markdown]
# ## Decision Tree, Random Forest & Isolation Forest Modelling

# %%
# Training the tree model with resampling methods
def train_tr(X_train_norm:pd.DataFrame,
             y_train:pd.DataFrame,
             tree_model:DecisionTreeClassifier or RandomForestClassifier or IsolationForest,
             iter:int = 10,
             rand_seed:int = 40,
             resample:str = None):
    
    # Check resample method input sanity
    if resample:
        assert resample=='ROS' or resample=='SMOTE',\
            f"resample can only be 'ROS' or 'SMOTE'"
    
    # Initialize an empty list to store the accuracy scores
    acc_scores = []
    prec_scores = []
    rec_scores = []
    spec_scores = []

    # Apply different resampling method to enlarge the bad actor sample size
    if resample == 'ROS': # Random Oversampling
        ros = RandomOverSampler(random_state=rand_seed)
        X_train_norm, y_train = ros.fit_resample(X_train_norm, y_train)
        print("Random oversampling actor distribution:")
        print(pd.Series(y_train).value_counts())
    elif resample == 'SMOTE': # Synthetic Minority Oversampling Technique
        smote = SMOTE(random_state=rand_seed)
        X_train_norm, y_train = smote.fit_resample(X_train_norm, y_train)
        print("SMOTE oversampling actor distribution:")
        print(pd.Series(y_train).value_counts())
    else: # No resampling
        print("Original actor distribution:")
        print(pd.Series(y_train).value_counts())
 
    for i in range(iter):
        # Split into training and validating sets
        X_ttrain, X_valid, y_ttrain, y_valid =\
            train_test_split(X_train_norm, y_train, stratify=y_train,
                              test_size=.2, random_state=rand_seed+i)
        
        # Train with the normalized training data
        tree_model.fit(X_ttrain, y_ttrain)
        
        # Evaluate the normalized validating data
        y_pred = tree_model.predict(X_valid)
        if type(tree_model) == IsolationForest:
            y_pred = np.where(y_pred == -1, 0, 1)
        accuracy = accuracy_score(y_valid, y_pred)
        precison = precision_score(y_valid, y_pred)
        recall = recall_score(y_valid, y_pred)
        specificity = recall_score(y_valid, y_pred, pos_label=0)

        # Add validation results to lists
        acc_scores.append(accuracy)
        prec_scores.append(precison)
        rec_scores.append(recall)
        spec_scores.append(specificity)

    # Show final result
    print('Average validation accuracy:', round(np.mean(acc_scores), 4))
    print('Average validation precision:', round(np.mean(prec_scores), 4))
    print('Average validation recall:', round(np.mean(rec_scores), 4))
    print('Average validation specificity:', round(np.mean(spec_scores), 4))

    # Return model results
    return tree_model, (np.mean(acc_scores), np.mean(prec_scores), np.mean(rec_scores), np.mean(spec_scores))


# Testing the logistic regression model with the test set
def test_tr(X_test:pd.DataFrame,
            y_test:pd.DataFrame,
            tr_model:DecisionTreeClassifier or RandomForestClassifier):
    
    # Generate test metrics
    y_test_pred = tr_model.predict(X_test)
    if type(tr_model) == IsolationForest:
        y_test_pred = np.where(y_test_pred == -1, 0, 1)

    # Metric result
    accuracy = accuracy_score(y_test, y_test_pred)
    precison = precision_score(y_test, y_test_pred)
    recall = recall_score(y_test, y_test_pred)
    specificity = recall_score(y_test, y_test_pred, pos_label=0)

    # Show final result
    print('Test accuracy:', round(accuracy, 4))
    print('Test precision:', round(precison, 4))
    print('Test recall:', round(recall, 4))
    print('Test specificity:', round(specificity, 4))
    return (accuracy, precison, recall, specificity)

# %% [markdown]
# ## Tree-Based Model Perfromance Analysis

# %%
# Basic decision tree approach
dt = DecisionTreeClassifier(random_state=7)

# Train and test
dt, mm8 = train_tr(X_train, y_train, dt)
m8 = test_tr(X_test, y_test, dt)

# Show confusion matrix
bad8, cm8 = show_confusion(dt, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(dt, X_train, X_test, y_train, y_test)

# Show coef of training set
plot_coefficient(dt, X_train) # need X_train's column names
# Out:
# Original actor distribution:
# False    799960
# True         40
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.9999
# Average validation precision: 0.01
# Average validation recall: 0.0125
# Average validation specificity: 1.0
# Test accuracy: 0.9999
# Test precision: 0.0
# Test recall: 0.0
# Test specificity: 0.9999

# %%
# Weighted sklearn hyperparameter approach
dt_sklearn = DecisionTreeClassifier(random_state=7, class_weight='balanced')

# Train and test
dt_sklearn, mm9 = train_tr(X_train, y_train, dt_sklearn)
m9 = test_tr(X_test, y_test, dt_sklearn)

# Show confusion matrix
bad9, cm9 = show_confusion(dt_sklearn, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(dt_sklearn, X_train, X_test, y_train, y_test)

# Show coef of training set
plot_coefficient(dt_sklearn, X_train) # need X_train's column names
# Out:
# Original actor distribution:
# False    799960
# True         40
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.9999
# Average validation precision: 0.0341
# Average validation recall: 0.0375
# Average validation specificity: 1.0
# Test accuracy: 0.9999
# Test precision: 0.0
# Test recall: 0.0
# Test specificity: 1.0

# %%
# Weighted sklearn hyperparameter approach
rf_sklearn = RandomForestClassifier(random_state=7, class_weight='balanced')

# Train and test
rf_sklearn, mm10 = train_tr(X_train, y_train, rf_sklearn, iter=1)
m10 = test_tr(X_test, y_test, rf_sklearn)

# Show confusion matrix
bad10, cm10 = show_confusion(rf_sklearn, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(rf_sklearn, X_train, X_test, y_train, y_test)

# Show coef of training set
plot_coefficient(rf_sklearn, X_train) # need X_train's column names
# Out:
# Original actor distribution:
# False    799960
# True         40
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 1.0
# Average validation precision: 0.0
# Average validation recall: 0.0
# Average validation specificity: 1.0
# Test accuracy: 1.0
# Test precision: 0.0
# Test recall: 0.0
# Test specificity: 1.0

# %%
# SMOTE approach
rf_smote = RandomForestClassifier(random_state=7)

# Train and test
rf_smote, mm11 = train_tr(X_train, y_train, rf_smote, iter=1, resample='SMOTE')
m11 = test_tr(X_test, y_test, rf_smote)

# Show confusion matrix
bad11, cm11 = show_confusion(rf_smote, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(rf_smote, X_train, X_test, y_train, y_test)

# Show coef of training set
plot_coefficient(rf_smote, X_train) # need X_train's column names
# Out:
# SMOTE oversampling actor distribution:
# False    799960
# True     799960
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.9999
# Average validation precision: 0.9999
# Average validation recall: 1.0
# Average validation specificity: 0.9999
# Test accuracy: 0.9999
# Test precision: 0.0
# Test recall: 0.0
# Test specificity: 0.9999

# %%
 # Basic isolation forest approach
isf = IsolationForest(random_state=0)

# Train and test
isf, mm12 = train_tr(X_train, y_train, isf)
m12 = test_tr(X_test, y_test, isf)

# Show confusion matrix
bad12, cm12 = show_confusion(isf, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(isf, X_train, X_test, y_train, y_test)
# Out:
# Original actor distribution:
# False    799960
# True         40
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.1604
# Average validation precision: 0.0
# Average validation recall: 0.3
# Average validation specificity: 0.1604
# Test accuracy: 0.158
# Test precision: 0.0
# Test recall: 0.7
# Test specificity: 0.158

# %%
# SMOTE approach
isf_smote = IsolationForest(random_state=0)

# Train and test
isf_smote, mm13 = train_tr(X_train, y_train, isf_smote, iter=1, resample='SMOTE')
m13 = test_tr(X_test, y_test, isf_smote)

# Show confusion matrix
bad13, cm13 = show_confusion(isf_smote, scaler, df, selected_features)

# Show train and test confusion matrix
plot_cm_roc(isf_smote, X_train, X_test, y_train, y_test)
# Out:
# SMOTE oversampling actor distribution:
# False    799960
# True     799960
# Name: BAD_STATUS, dtype: int64
# Average validation accuracy: 0.3933
# Average validation precision: 0.4264
# Average validation recall: 0.6186
# Average validation specificity: 0.168
# Test accuracy: 0.166
# Test precision: 0.0
# Test recall: 0.8
# Test specificity: 0.166

# %%
# Gather all previous metrics
df_train_metric = pd.DataFrame({'LogisticRegression': mm1,
                               'LogisticRegression Weighted': mm2,
                               'LogisticRegression SEMOTE': mm3,
                               'LogisticRegression ROS': mm4,
                               'OneClassSVM': mm5,
                               'OneClassSVM SEMOTE': mm6,
                               'OneClassSVM ROS': mm7,
                               'DecisionTree': mm8,
                               'DecisionTree Weighted': mm9,
                               'RandomForest Weighted': mm10,
                               'RandomForest SEMOTE': mm11,
                               'IsolationForest': mm12,
                               'IsolationForest SEMOTE': mm13},
                               index=['Accuracy Validation',
                                      'Precision Validation',
                                      'Recall Validation',
                                      'Specificity Validation'])
df_test_metric = pd.DataFrame({'LogisticRegression': m1,
                               'LogisticRegression Weighted': m2,
                               'LogisticRegression SEMOTE': m3,
                               'LogisticRegression ROS': m4,
                               'OneClassSVM': m5,
                               'OneClassSVM SEMOTE': m6,
                               'OneClassSVM ROS': m7,
                               'DecisionTree': m8,
                               'DecisionTree Weighted': m9,
                               'RandomForest Weighted': m10,
                               'RandomForest SEMOTE': m11,
                               'IsolationForest': m12,
                               'IsolationForest SEMOTE': m13},
                                index=['Accuracy Test',
                                       'Precision Test',
                                       'Recall Test',
                                       'Specificity Test'])

# %%
df_train_metric
# Out:
#                         LogisticRegression  LogisticRegression Weighted  \
# Accuracy Validation                0.99995                     0.858471
# Precision Validation               0.00000                     0.000233
# Recall Validation                  0.00000                     0.662500
# Specificity Validation             1.00000                     0.858480
#
#                         LogisticRegression SEMOTE  LogisticRegression ROS  \
# Accuracy Validation                      0.788446                0.784616
# Precision Validation                     0.858529                0.842924
# Recall Validation                        0.690709                0.699601
# Specificity Validation                   0.886182                0.869632
#
#                         OneClassSVM  OneClassSVM SEMOTE  OneClassSVM ROS  \
# Accuracy Validation        0.481044            0.701589         0.708604
# Precision Validation       0.000056            0.701907         0.706694
# Recall Validation          0.525000            0.714323         0.725149
# Specificity Validation     0.481042            0.688856         0.692060
#
#                         DecisionTree  DecisionTree Weighted  \
# Accuracy Validation         0.999902               0.999902
# Precision Validation        0.010000               0.034091
# Recall Validation           0.012500               0.037500
# Specificity Validation      0.999952               0.999951
#
#                         RandomForest Weighted  RandomForest SEMOTE  \
# Accuracy Validation                   0.99995             0.999931
# Precision Validation                  0.00000             0.999906
# Recall Validation                     0.00000             0.999956
# Specificity Validation                1.00000             0.999906
#
#                         IsolationForest  IsolationForest SEMOTE
# Accuracy Validation            0.160419                0.393304
# Precision Validation           0.000018                0.426448
# Recall Validation              0.300000                0.618618
# Specificity Validation         0.160412                0.167990

# %%
df_test_metric
# Out:
#                   LogisticRegression  LogisticRegression Weighted  \
# Accuracy Test                0.99995                     0.858410
# Precision Test               0.00000                     0.000247
# Recall Test                  0.00000                     0.700000
# Specificity Test             1.00000                     1.000000
#
#                   LogisticRegression SEMOTE  LogisticRegression ROS  \
# Accuracy Test                      0.886520                0.869870
# Precision Test                     0.000352                0.000269
# Recall Test                        0.800000                0.700000
# Specificity Test                   1.000000                1.000000
#
#                   OneClassSVM  OneClassSVM SEMOTE  OneClassSVM ROS  \
# Accuracy Test        0.520455            0.683355         0.506985
# Precision Test       0.000073            0.000111         0.000071
# Recall Test          0.700000            0.700000         0.700000
# Specificity Test     1.000000            1.000000         1.000000
#
#                   DecisionTree  DecisionTree Weighted  RandomForest Weighted  \
# Accuracy Test         0.999875               0.999905                0.99995
# Precision Test        0.000000               0.000000                0.00000
# Recall Test           0.000000               0.000000                0.00000
# Specificity Test      0.999925               0.999955                1.00000
#
#                   RandomForest SEMOTE  IsolationForest  IsolationForest SEMOTE
# Accuracy Test                0.999865         0.158050                0.165995
# Precision Test               0.000000         0.000042                0.000048
# Recall Test                  0.000000         0.700000                0.800000
# Specificity Test             0.999915         0.158023                0.165963
